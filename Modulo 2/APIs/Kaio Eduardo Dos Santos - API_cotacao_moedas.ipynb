# %% [markdown]
# # Python e API
#
# ### O que é uma API?
#
# - É um conjunto de códigos para usar um serviço/site/aplicativo específico. Cada site/ferramenta tem sua própria API. É importante que você saiba ler as APIs que precisar para saber usar
#
# - Um dos padrões mais comuns em API é pegar informações em formato json, uma espécie de dicionário que precisa ser tratada no Python para podermos analisar
#
# - As possibilidades de API são infinitas, vamos fazer 2 exemplos aqui: Cotação de Moedas e Envio de SMS.
#
# - Sites como Google, Youtube, Facebook, Twitter, ArcGis e praticamente qualquer ferramenta/site grande tem uma API.
#
# ### O que precisamos:
#
# - Quase sempre você precisa de uma conta para consumir uma API. Algumas APIs são abertas, como a https://docs.awesomeapi.com.br/api-de-moedas , mas em muitos casos vamos precisar ter uma conta ativa para consumir a API
#
# - A Documentação da API (ou exemplos da internet) é a chave para conseguir usar uma API

# %% [markdown]
# #### Pegar a Cotação Atual de Todas as Moedas

# %%
import requests
import json

cotacao = requests.get('https://economia.awesomeapi.com.br/json/all')
cotacao_dic = cotacao.json()
print(cotacao)
print(cotacao_dic)
# Out:
# <Response [200]>
# {'USD': {'code': 'USD', 'codein': 'BRL', 'name': 'Dólar Americano/Real Brasileiro', 'high': '5.5095', 'low': '5.45735', 'varBid': '-0.0263', 'pctChange': '-0.478331', 'bid': '5.472', 'ask': '5.475', 'timestamp': '1755713160', 'create_date': '2025-08-20 15:06:00'}, 'USDT': {'code': 'USD', 'codein': 'BRLT', 'name': 'Dólar Americano/Real Brasileiro Turismo', 'high': '5.54894', 'low': '5.49642', 'varBid': '-0.02649', 'pctChange': '-0.478363', 'bid': '5.51117', 'ask': '5.68156', 'timestamp': '1755713160', 'create_date': '2025-08-20 15:06:00'}, 'CAD': {'code': 'CAD', 'codein': 'BRL', 'name': 'Dólar Canadense/Real Brasileiro', 'high': '3.96904', 'low': '3.93648', 'varBid': '-0.018819', 'pctChange': '-0.475164', 'bid': '3.94172', 'ask': '3.9518', 'timestamp': '1755713136', 'create_date': '2025-08-20 15:05:36'}, 'GBP': {'code': 'GBP', 'codein': 'BRL', 'name': 'Libra Esterlina/Real Brasileiro', 'high': '7.44023', 'low': '7.34754', 'varBid': '-0.03635', 'pctChange': '-0.491086', 'bid': '7.36558', 'ask': '7.36962', 'timestamp': '1755713160', 'create_date': '2025-08-20 15:06:00'}, 'ARS': {'code': 'ARS', 'codein': 'BRL', 'name': 'Peso Argentino/Real Brasileiro', 'high': '0.00426851', 'low': '0.0041931', 'varBid': '-0.000055', 'pctChange': '-1.296567', 'bid': '0.00420294', 'ask': '0.00421368', 'timestamp': '1755713136', 'create_date': '2025-08-20 15:05:36'}, 'BTC': {'code': 'BTC', 'codein': 'BRL', 'name': 'Bitcoin/Real Brasileiro', 'high': '629150', 'low': '615800', 'varBid': '841', 'pctChange': '0.135', 'bid': '623809', 'ask': '623810', 'timestamp': '1755713162', 'create_date': '2025-08-20 15:06:02'}, 'LTC': {'code': 'LTC', 'codein': 'BRL', 'name': 'Litecoin/Real Brasileiro', 'high': '638.1', 'low': '615.2', 'varBid': '6.3', 'pctChange': '1.004', 'bid': '633.2', 'ask': '633.5', 'timestamp': '1755713159', 'create_date': '2025-08-20 15:05:59'}, 'EUR': {'code': 'EUR', 'codein': 'BRL', 'name': 'Euro/Real Brasileiro', 'high': '6.41437', 'low': '6.36537', 'varBid': '-0.020374', 'pctChange': '-0.318647', 'bid': '6.37349', 'ask': '6.38978', 'timestamp': '1755713136', 'create_date': '2025-08-20 15:05:36'}, 'JPY': {'code': 'JPY', 'codein': 'BRL', 'name': 'Iene Japonês/Real Brasileiro', 'high': '0.03736584', 'low': '0.03703694', 'varBid': '-0.000033', 'pctChange': '-0.089857', 'bid': '0.03717947', 'ask': '0.03719985', 'timestamp': '1755713160', 'create_date': '2025-08-20 15:06:00'}, 'CHF': {'code': 'CHF', 'codein': 'BRL', 'name': 'Franco Suíço/Real Brasileiro', 'high': '6.82035', 'low': '6.76984', 'varBid': '0.001357', 'pctChange': '0.019962', 'bid': '6.79944', 'ask': '6.81682', 'timestamp': '1755713136', 'create_date': '2025-08-20 15:05:36'}, 'AUD': {'code': 'AUD', 'codein': 'BRL', 'name': 'Dólar Australiano/Real Brasileiro', 'high': '3.54671', 'low': '3.50961', 'varBid': '-0.028271', 'pctChange': '-0.797653', 'bid': '3.51601', 'ask': '3.525', 'timestamp': '1755713136', 'create_date': '2025-08-20 15:05:36'}, 'CNY': {'code': 'CNY', 'codein': 'BRL', 'name': 'Yuan Chinês/Real Brasileiro', 'high': '0.76547986', 'low': '0.76011682', 'varBid': '-0.002891', 'pctChange': '-0.377611', 'bid': '0.76258933', 'ask': '0.76462121', 'timestamp': '1755712796', 'create_date': '2025-08-20 14:59:56'}, 'ILS': {'code': 'ILS', 'codein': 'BRL', 'name': 'Novo Shekel Israelense/Real Brasileiro', 'high': '1.620054', 'low': '1.597577', 'varBid': '-0.017139', 'pctChange': '-1.059075', 'bid': '1.601158', 'ask': '1.605884', 'timestamp': '1755712973', 'create_date': '2025-08-20 15:02:53'}, 'ETH': {'code': 'ETH', 'codein': 'BRL', 'name': 'Ethereum/Real Brasileiro', 'high': '23901', 'low': '22459.11', 'varBid': '641.49', 'pctChange': '2.797', 'bid': '23569.4', 'ask': '23570.98', 'timestamp': '1755713163', 'create_date': '2025-08-20 15:06:03'}, 'XRP': {'code': 'XRP', 'codein': 'BRL', 'name': 'XRP/Real Brasileiro', 'high': '16.189', 'low': '15.445', 'varBid': '-0.064', 'pctChange': '-0.398', 'bid': '16.023', 'ask': '16.024', 'timestamp': '1755713163', 'create_date': '2025-08-20 15:06:0 ...

# %% [markdown]
# #### Qual foi a última cotação do Dólar, do Euro e do BitCoin?

# %%
print(f"O Dolar hoje : {cotacao_dic['USD']['bid']} MDS DO CÉU BERG 🚨🚨🚨!!!")
print(f"O Euro hoje está a : {cotacao_dic['EUR']['bid']} MDS 💵💵💵!!")
print(f"O Bitcoin hoje está a : {cotacao_dic['BTC']['bid']} compre bitcoin urgente 📊📉!!")
# Out:
# O Dolar hoje : 5.472 MDS DO CÉU BERG 🚨🚨🚨!!!
# O Euro hoje está a : 6.37349 MDS 💵💵💵!!
# O Bitcoin hoje está a : 623809 compre bitcoin urgente 📊📉!!

# %% [markdown]
# #### Pegar a cotação dos últimos 30 dias do dólar

# %%
cotacao30_dias = requests.get('https://economia.awesomeapi.com.br/json/daily/USD-BRL/30')
cotacao30_dic = cotacao30_dias.json()


#usando o for
for item in cotacao30_dic:
    print(f"No dia {item['timestamp']} a cotação do dolar foi de {float(item['bid'])}")
# Out:
# No dia 1755525502 a cotação do dolar foi de 5.4091
# No dia 1755474937 a cotação do dolar foi de 5.396
# No dia 1755292986 a cotação do dolar foi de 5.3959
# No dia 1755215955 a cotação do dolar foi de 5.40178
# No dia 1755129514 a cotação do dolar foi de 5.3913
# No dia 1755039834 a cotação do dolar foi de 5.4014
# No dia 1754956773 a cotação do dolar foi de 5.4424
# No dia 1754870218 a cotação do dolar foi de 5.4322
# No dia 1754688456 a cotação do dolar foi de 5.4268
# No dia 1754610953 a cotação do dolar foi de 5.4142
# No dia 1754524717 a cotação do dolar foi de 5.4588
# No dia 1754438343 a cotação do dolar foi de 5.5016
# No dia 1754351973 a cotação do dolar foi de 5.496
# No dia 1754265434 a cotação do dolar foi de 5.52993
# No dia 1754082880 a cotação do dolar foi de 5.5338
# No dia 1754006283 a cotação do dolar foi de 5.5987
# No dia 1753919913 a cotação do dolar foi de 5.5764
# No dia 1753833544 a cotação do dolar foi de 5.5733
# No dia 1753747173 a cotação do dolar foi de 5.5867
# No dia 1753660565 a cotação do dolar foi de 5.55597
# No dia 1753478932 a cotação do dolar foi de 5.5565
# No dia 1753401516 a cotação do dolar foi de 5.51657
# No dia 1753315128 a cotação do dolar foi de 5.5165
# No dia 1753228723 a cotação do dolar foi de 5.56062
# No dia 1753142393 a cotação do dolar foi de 5.5658
# No dia 1753055808 a cotação do dolar foi de 5.57588
# No dia 1752873374 a cotação do dolar foi de 5.5755
# No dia 1752796692 a cotação do dolar foi de 5.5486
# No dia 1752710317 a cotação do dolar foi de 5.56297
# No dia 1752623951 a cotação do dolar foi de 5.5559

# %% [markdown]
# ####Agora é sua vez faça o mesmo código anterior, porém queremos saber a cotação do **EURO** (EUR-BRL), Além disso um desafio extra!! tente resolver o a questão do **timestamp** convertendo o número para **data** e exibindo ele convertido no print.

# %%
#primeiro importando a biblioteca
import requests
import json
from datetime import datetime
#pegando a cotação dos ultimos 30 dias, porém do euro agora.
cotacao30_dias = requests.get('https://economia.awesomeapi.com.br/json/daily/EUR-BRL/30')
cotacao30_dic = cotacao30_dias.json()

#usando o for para percorrer o dicionário e printar o timestamp convertido além da cotação do euro
for item in cotacao30_dic:

    dt_object = datetime.fromtimestamp(int(item['timestamp']))
    data_formatada = dt_object.strftime("%d-%m-%Y")
    print(f"no dia {data_formatada} a cotação do Euro foi de {float(item['bid'])}")
# Out:
# no dia 20-08-2025 a cotação do Euro foi de 6.37349
# no dia 19-08-2025 a cotação do Euro foi de 6.39386
# no dia 18-08-2025 a cotação do Euro foi de 6.33714
# no dia 17-08-2025 a cotação do Euro foi de 6.31712
# no dia 15-08-2025 a cotação do Euro foi de 6.31712
# no dia 14-08-2025 a cotação do Euro foi de 6.29327
# no dia 13-08-2025 a cotação do Euro foi de 6.30915
# no dia 12-08-2025 a cotação do Euro foi de 6.3012
# no dia 11-08-2025 a cotação do Euro foi de 6.31313
# no dia 10-08-2025 a cotação do Euro foi de 6.32511
# no dia 08-08-2025 a cotação do Euro foi de 6.32111
# no dia 07-08-2025 a cotação do Euro foi de 6.31313
# no dia 06-08-2025 a cotação do Euro foi de 6.35728
# no dia 05-08-2025 a cotação do Euro foi de 6.36537
# no dia 04-08-2025 a cotação do Euro foi de 6.35728
# no dia 03-08-2025 a cotação do Euro foi de 6.40615
# no dia 01-08-2025 a cotação do Euro foi de 6.41849
# no dia 31-07-2025 a cotação do Euro foi de 6.39386
# no dia 30-07-2025 a cotação do Euro foi de 6.36943
# no dia 29-07-2025 a cotação do Euro foi de 6.43087
# no dia 28-07-2025 a cotação do Euro foi de 6.47249
# no dia 27-07-2025 a cotação do Euro foi de 6.53168
# no dia 25-07-2025 a cotação do Euro foi de 6.52742
# no dia 24-07-2025 a cotação do Euro foi de 6.48508
# no dia 23-07-2025 a cotação do Euro foi de 6.48929
# no dia 22-07-2025 a cotação do Euro foi de 6.52742
# no dia 21-07-2025 a cotação do Euro foi de 6.50195
# no dia 20-07-2025 a cotação do Euro foi de 6.48508
# no dia 18-07-2025 a cotação do Euro foi de 6.48088
# no dia 17-07-2025 a cotação do Euro foi de 6.43501

# %% [markdown]
# #### Pegar as cotações do BitCoin de Jan/20 a Out/20

# %%
cotacao_btc = requests.get('https://economia.awesomeapi.com.br/BTC-BRL/100?start_date=20250101&end_date=20250820')
cotacao_btc_dic = cotacao_btc.json()
#list
lista_cotacoes_btc = [float(item['bid']) for item in cotacao_btc_dic]
print(lista_cotacoes_btc)
lista_cotacoes_btc.reverse()
# Out:
# [623136.0, 622732.0, 622949.0, 622569.0, 622800.0, 622871.0, 622886.0, 622304.0, 622418.0, 622603.0, 622624.0, 622624.0, 622708.0, 622833.0, 622849.0, 623013.0, 622889.0, 622889.0, 623165.0, 623453.0, 623106.0, 622952.0, 622937.0, 623005.0, 622999.0, 623122.0, 623518.0, 624028.0, 623856.0, 624176.0, 624462.0, 624554.0, 624035.0, 623433.0, 623005.0, 623134.0, 623395.0, 623576.0, 623362.0, 623315.0, 623365.0, 623123.0, 623310.0, 623557.0, 623247.0, 623000.0, 623733.0, 624043.0, 623911.0, 623521.0, 623061.0, 623212.0, 623329.0, 623371.0, 623149.0, 623349.0, 623333.0, 623609.0, 623608.0, 623733.0, 623699.0, 623653.0, 623653.0, 623700.0, 623770.0, 623798.0, 623972.0, 623570.0, 623626.0, 623447.0, 623572.0, 623501.0, 623533.0, 623805.0, 623967.0, 624177.0, 624067.0, 624057.0, 624220.0, 624345.0, 624574.0, 624584.0, 624484.0, 624428.0, 624450.0, 624550.0, 624329.0, 624177.0, 624066.0, 623937.0, 623965.0, 623951.0, 624203.0, 624338.0, 624189.0, 624176.0, 624247.0, 624219.0, 624015.0, 624015.0]

# %% [markdown]
# ### Agora sua vez pegue as cotações do Dolar no ano inteiro de 2024 ou seja de Jan/24 a Dez/24

# %%
# primeiro importe a biblioteca
import requests
import json
from datetime import datetime

cotacao_dol = requests.get('https://economia.awesomeapi.com.br/USD-BRL/100?start_date=20240101&end_date=20241231')
cotacao_dol_dic = cotacao_dol.json()
#list
lista_cotacoes_dol = [float(item['bid']) for item in cotacao_dol_dic]
print(lista_cotacoes_dol)
lista_cotacoes_dol.reverse()
# Out:
# [6.184, 6.184, 6.184, 6.184, 6.184, 6.184, 6.184, 6.1778, 6.1778, 6.1778, 6.1773, 6.1768, 6.1793, 6.1778, 6.1783, 6.1768, 6.1763, 6.1773, 6.1813, 6.1818, 6.1818, 6.1818, 6.1806, 6.1801, 6.1823, 6.1806, 6.1803, 6.1791, 6.1803, 6.1803, 6.1818, 6.1798, 6.1786, 6.1786, 6.1781, 6.1781, 6.1771, 6.1771, 6.1761, 6.1781, 6.1786, 6.1798, 6.1798, 6.1786, 6.1766, 6.1771, 6.1756, 6.1756, 6.1773, 6.1761, 6.1756, 6.1773, 6.1761, 6.1771, 6.1771, 6.1768, 6.1771, 6.1771, 6.1786, 6.1788, 6.178, 6.1775, 6.1781, 6.179, 6.1796, 6.1805, 6.1805, 6.178, 6.1786, 6.1791, 6.1792, 6.1813, 6.1813, 6.1803, 6.1786, 6.1776, 6.1778, 6.1766, 6.1781, 6.18, 6.1811, 6.178, 6.178, 6.1801, 6.1791, 6.1766, 6.1766, 6.176, 6.1775, 6.1786, 6.1786, 6.1778, 6.1755, 6.1791, 6.1743, 6.1723, 6.1721, 6.1705, 6.1701, 6.1738]

# %% [markdown]
# ### Gráfico com as cotações do BitCoin

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.plot(lista_cotacoes_btc)
plt.show()
