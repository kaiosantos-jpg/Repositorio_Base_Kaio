# %%
import pyautogui as aut

# %%
aut.press("Win") 
aut.sleep(0.4)
aut.write("Bloco de notas",interval=0.3)
aut.sleep(0.4)
aut.press("Enter")
aut.sleep(0.5)
aut.write("adoro dormir", interval=0.2)

# %%
#Abrir o chrome pelo windows
aut.press("Win")
aut.sleep(0.5)
aut.write("Chrome", interval=0.15)
aut.press("Enter")
#Pesquisar google sites
aut.moveTo(339,63)
aut.sleep(1)
aut.click()
aut.write("Google sites", interval= 0.1)
aut.press("Enter")
#Entrar no portifólio
aut.moveTo(273,312)
aut.sleep(1)
aut.click()
#Passo de publicação
aut.sleep(1)
aut.moveTo(480,573)
aut.sleep(2)
aut.click()
aut.sleep(1)
aut.moveTo(1797,118)
aut.sleep(3)
aut.click()
aut.moveTo(1286,848)
aut.sleep(5)
aut.click()
aut.sleep(3)
#Clicar em publicar
aut.moveTo(1135,755)
aut.sleep(5)
aut.click()
#Confirmar o envio
aut.moveTo(292,20)
aut.sleep(1)
aut.click()
#Abrir nova aba e colocar o site
aut.moveTo(288,64)
aut.sleep(2)
aut.click()
aut.write("https://sites.google.com/view/kaioeduardosantos", interval=0.1)
#Inspecionar o site
aut.sleep(2)
aut.press("Enter")
aut.sleep(1)
aut.press("F11")
aut.sleep(7)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)
aut.sleep(1)
aut.scroll(-300)

# %%
aut.mouseInfo()

# %%
# ABRIR O CHROME PELO WINDOWS
aut.press("Win")
aut.sleep(0.5)
aut.write("Chrome", interval=0.1)
aut.press("Enter")
aut.sleep(3)
#PESQUISAR A IMAGEM DESEJADA
aut.write("Cristiano ronaldo 2008 manchester united", interval= 0.05)
aut.press("Enter")
aut.sleep(1)
aut.moveTo(328,196)
aut.sleep(1)
aut.click()
#ESCOLHER A IMAGEM 
aut.moveTo(551,431)
aut.sleep(1)
aut.click()
aut.sleep(1)
#BAIXAR A IMAGEM
aut.moveTo(1506,588)
aut.sleep(1)
aut.rightClick()
aut.moveTo(1510,434)
aut.sleep(1)
aut.click()
#SALVAR NO EXPLORADOR DE ARQUIVOS
aut.moveTo(790,501)
aut.sleep(1)
aut.click()
#ABRIR NOVA ABA
aut.moveTo(287,21)
aut.sleep(1)
aut.click()
#ABRIR GMAIL
aut.moveTo(1835,112)
aut.sleep(1)
aut.click()
aut.sleep(1)
aut.moveTo(1730,223)
aut.sleep(1)
aut.click()
aut.sleep(5)
#MANDAR O EMAIL
aut.moveTo(148,185)
aut.sleep(1)
aut.click()
aut.sleep(1)
aut.write("1103092716@aluno.santanadeparnaiba.sp.gov.br", interval=0.05)
aut.sleep(1)
aut.press("Enter")
aut.sleep(2)
#ANEXAR A IMAGEM
aut.moveTo(1425,1000)
aut.sleep(1)
aut.click()
aut.moveTo(93,295)
aut.sleep(1)
aut.click()
aut.sleep(1)
aut.moveTo(304,166)
aut.doubleClick()
#DIGITAR MENSAGEM
aut.moveTo(1289,564)
aut.sleep(1)
aut.click()
aut.write("Esse foi o melhor prime do cristiano ronaldo", interval=0.08)
#ENVIAR EMAIL
aut.moveTo(1315,1000)
aut.sleep(1)
aut.click()
aut.sleep(5)
#FECHAR ABAS
aut.moveTo(1897,18)
aut.sleep(1)
aut.click()
#ABRIR VSCODE
aut.sleep(2)
aut.moveTo(1170,1055)
aut.sleep(1)
aut.click()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 6
#       4 aut.write("Chrome", interval=0.1)
#       5 aut.press("Enter")
# ----> 6 aut.sleep(3)
#       7 #PESQUISAR A IMAGEM DESEJADA
#       8 aut.write("Cristiano ronaldo 2008 manchester united", interval= 0.05)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pyautogui\__init__.py:1806, in sleep(seconds)
#    1805 def sleep(seconds):
# -> 1806     time.sleep(seconds)
#
# KeyboardInterrupt:

# %%
#ABRIR CHROME
aut.press("Win")
aut.sleep(1)
aut.write("Chrome", interval=0.05)
aut.sleep(1)
aut.press("Enter")
aut.sleep(2)
#PESQUISAR O SITE DO WHATSAPP WEB
aut.moveTo(307,65)
aut.sleep(1)
aut.click()
aut.write("Whatsapp web",interval=0.05)
aut.sleep(1)
aut.press("Enter")
#ENTRAR NO WHATSAPP WEB
aut.sleep(1)
aut.moveTo(271,292)
aut.sleep(1)
aut.click()
aut.sleep(7)
#PESQUISAR CONTATO
aut.moveTo(392,190)
aut.sleep(0.5)
aut.click()
aut.write("miguel",interval=0.05)
aut.sleep(1)
#WNTRAR NO CONTATO
aut.moveTo(419,426)
aut.sleep(1)
aut.click()
aut.sleep(2)
#ENVIAR MENSAGEM
aut.write("BALEIA AZUL, MACACO PRETO",interval=0.05)
aut.press("Enter")
